# %%
print("Hello from python")
# Out:
# Hello from python

# %%
print("A sum of two numbers")
print(5 + 9)
# Out:
# A sum of two numbers
# 14

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
number = 100
values2 = np.random.normal(loc=54, scale=5,size=(number))
values1 = np.arange(0,number)

# %%
plt.plot(values1, values2)

# %% [markdown]
# $ \text{Este es un texto en \latex} $
